# %% [markdown]
# <a href="https://colab.research.google.com/github/natdebandi/hate_speech_ar/blob/main/Pruebas_DATASET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TP final - reconocimiento de discursos discriminatorios en Twitter
#
# **Natalia Dedandi**
#
# En esta noebook se realizan pruebas

# %%
# !pip install datasets seaborn
# Out:
# Collecting datasets
#   Downloading datasets-2.20.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.1.4)
# Collecting requests>=2.32.2 (from datasets)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.4)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.5.0,>=2023.1.0 (from fsspec[http]<=2024.5.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.5.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.7.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.7.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading datasets-2.20.0-py3-none-any.whl (547 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 9.1 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 5.5 MB/s eta 0:00:00
# Downloading fsspec-2024.5.0-py3-none-any.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.1/316.1 kB 11.8 MB/s eta 0:00:00
# Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 11.6 MB/s eta 0:00:00
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 2.9 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.7 MB/s eta 0:00:00
# Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 7.9 MB/s eta 0:00:00
# Installing collected packages: xxhash, requests, pyarrow, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.6.1
#     Uninstalling fsspec-2024.6.1:
#       Successfully uninstalled fsspec-2024.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.3.1+cu121 requires nvidia-cublas-cu12==12.1.3.1; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cuda-cupti-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cuda-nvrtc-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cuda-runtime-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cudnn-cu12==8.9.2.26; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cufft-cu12==11.0.2.54; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-curand-cu12==10.3.2.106; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cusolver-cu12==11.4.5.107; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-cusparse-cu12==12.1.0.106; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-nccl-cu12==2.20.5; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# torch 2.3.1+cu121 requires nvidia-nvtx-cu12==12.1.105; platform_system == "Linux" and platform_machine == "x86_64", which is not installed.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# gcsfs 2024.6.1 requires fsspec==2024.6.1, but you have fsspec 2024.5.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# Successfully installed datasets-2.20.0 dill-0.3.8 fsspec-2024.5.0 multiprocess-0.70.16 pyarrow-17.0.0 requests-2.32.3 xxhash-3.4.1

# %%
from datasets import load_dataset
import pandas as pd

ds1 = load_dataset("piuba-bigdata/contextualized_hate_speech")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading readme:   0%|          | 0.00/3.55k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/1.98k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/107M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.52M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/26.8M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/36420 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/11343 [00:00<?, ? examples/s]
# Generating dev split:   0%|          | 0/9106 [00:00<?, ? examples/s]

# %%
ds1
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'title', 'text', 'context_tweet', 'HATEFUL', 'body', 'CALLS', 'WOMEN', 'LGBTI', 'RACISM', 'CLASS', 'POLITICS', 'DISABLED', 'APPEARANCE', 'CRIMINAL'],
#         num_rows: 36420
#     })
#     test: Dataset({
#         features: ['id', 'title', 'text', 'context_tweet', 'HATEFUL', 'body', 'CALLS', 'WOMEN', 'LGBTI', 'RACISM', 'CLASS', 'POLITICS', 'DISABLED', 'APPEARANCE', 'CRIMINAL'],
#         num_rows: 11343
#     })
#     dev: Dataset({
#         features: ['id', 'title', 'text', 'context_tweet', 'HATEFUL', 'body', 'CALLS', 'WOMEN', 'LGBTI', 'RACISM', 'CLASS', 'POLITICS', 'DISABLED', 'APPEARANCE', 'CRIMINAL'],
#         num_rows: 9106
#     })
# })

# %%
# prompt: print the text form ds1 where WOMEN is true

#df = ds1['train'].to_pandas()
df_filter = df[df['CALLS']==True]
#for index, row in df_filter.iterrows():
##  print(row['text'])
# Out:
# @usuario Bala y a otra cosa. No hay que tener piedad con estos hijos de puta REINCIDENTES COMPROBADOS que arruinan familias.
# @usuario no vayan al super chino
# @usuario Córtenle la chota y nunca más va a violar hdp.
# @usuario Pena de muerte
# @usuario Castración y muerte
# @usuario Creo q es una buena oportunidad de tener nuestro Carandiru... metan bala y listo , muerto el perro se acabó la rabia
# @usuario Pena de muerte para estos criminales! si ahora se puede matar a un bebé inocente en la panza me imagino que se debería poder condenar a muerte a esta gente no?
# @usuario El corchazo que le pongo sería histórico. Hdp
# @usuario Que vivan los policías y que mueran los cacos.
# @usuario Cárcel, obligarlos a que se cojan entre ellos durante una semana y doce balazos para cada uno. Fin. Violador muerto no viola más.
# @usuario Y alguien los liquido? Sino no me interesa
# @usuario Cumpli tu dese que nos ahorras mucha plata a los ciudadanos y dejas un puesto vacante para otro
# @usuario chip de plomo al cerebro.
# @usuario A encerrar a China en un domo...
# @usuario Ahi tendrian q aprovechar y largar una balacera
# @usuario Berni m gustaría saber q pija haces en este gobierno populacho de zurdos de mierda. Media pila berni mas huevos y caga a balazos a estos wachos d mierda cn 9 o 10 años adelante d los hnos q aprendan en un año limpiamos la argentina. Buenos días y buenas noches van a decir después
# @usuario Hay que matarlos hijos de puta 😑
# @usuario Lo tienen que bajar a los tiros... malditos derechos humanos...
# @usuario Ahi esta!!! Despues cuestionan a la persona que dice que hay  que matarlos a los chorros!! HAY QUE MATARLOS SIN PIEDAD, SON ELLOS O NOSOTROS!!! Los periodiistas siempre a favor de Los chorros!!!
# @usuario Estas ratas con un gobierno enserio deben desaparecer.
# @usuario Apenas empezo a avanzar el tipo con el cuchi, 10 tiros..
# @usuario Deberían hacer una frontera y que maten solos
# @usuario Siempre china déjense d joder Trump invadilos d una vez
# @usuario @usuario Como se Llama el ERP.. DEL 2020???..ESTO SOLO SE SOLUCIONA MATANDO A VARIOS!!!
# @usuario Hay que devolverlos a sus países con moñito. Acá viven gratis y encima no acatan órdenes. Una patadita en el culo y a su pais.
# @usuario Si son Bolitas no los atiendan...
# @usuario Honestamente sacarle las córneas y riñones para transplante y el resto al tacho de basura o alimento para chanchos.
# @usuario Buen momento para tomar las armas
# @usuario Bala
# @usuario Todos delincuentes, habría que sacarlos de la cárcel y fusilarlos en el obelisco
# @usuario Q vayan tds.asi desaparecen inos cuantos kk.
# @usuario Estos chinos deberían vivir en una burbuja y no salir más!
# @usuario balas para los chorros
# @usuario @usuario Clásico de comunista, la embarran y se tapan entre ellos. Son un asco hay que extirparlos.!!!
# @usuario Habrá que organizarse...
# @usuario Ellos fueron los que regaron el virus maldito por el mundo. Por estar comiendo porquerias. Esa hente deben desaparecerlos. Matan a las ballenas,elefantes, tiburones. Son unos Asesinos😡 van a acabar con el mundo😪
# @usuario Bala y fuego!
# @usuario Que los envíen a Inglaterra para una tardía devolución de gentilezas
# @usuario Haga patria, mate a un chorro.
# UNO MENOS
# @usuario C A S T R A C I O N
# @usuario Balas para todos!! O una combitena perfecta: bala y topadora!!
# @usuario Justicia por mano propia es la unica que queda
# @usuario Silla eléctrica a ese hijo de puta
# @usuario De por tar los
# @usuario MUERTE LENTA A LOS HDP
# @usuario Matenló
# @usuario Yo propongo comer Chinos!!!
# @usuario Bala.
# @usuario Una bomba y que se mueran todas esas sucias
# @usuario Cuando los propietarios la defiendan a escopetazos no los quiero ver llorando sobre los caídos.
# @usuario A estos si hay que echarlos a patasas
# @usuario Háganlos ozono
# @usuario ¿Polémica ley? En cualquier país que se respete a sí mismo tiene leyes duras contra los inmigrantes ilegales.
#
# En Argentina tenemos que hacer lo mismo. Es inviable un país que sostiene a los pobres que ingresan en busca de subsidios y servicios gratis.
# @usuario 1- y deberían ser 20-
# @usuario @usuario Esta es la justicia ARGENTINA CON LOS JUECES INÚTILES QUE LOS LIBERAN UN TIRO EN LA CIEN DEBERÍAN PEGARLE A LOS JUECES.
# @usuario Tiro y al rio
# @usuario Habrá una oleada de gente amándose para esperarlos Juansito!!
# @usuario Esos hdp hay que cocinarlos a ellos vivos y tirarlos en una olla
# @usuario garrote y garrote!!!!!
# @usuario Bala....meta bala con alcohol en gel
# @usuario 3 tiros
# @usuario Disculpen mi ignorancia, pero no deberiamos pedir todos los países en todo caso (obvio que ahora no porque estamos ocupados) que China se haga cargo de los daños provocados? En Italia por ejemplo los hicieron mierda, en España...acá no sabemos cuánto falta (ojalá que no mucho)...
# @usuario Pena de muerte
# @usuario Hay que torturarlo hasta que muera por bastardo enfermo de porqueria
# @usuario Cierren las alcantarillas
# @usuario Chinos de mierda, sucios y soretes, ojala desaparezcan.
# @usuario Creo que ya es hora de que los productores se empiecen a olvidar cables pelados apoyados en el alambrado...
# @usuario Una bala y a otra cosa, no dilapidamos recursos
# @usuario Y acá los sueltan por la gripezhinia trola esta....ayyy pobrecitos
#
# Bala
# @usuario Rajenlos a su país de origen y a los sensibles averigüen q pasa si un no boliviano va a atenderse en ese país
# @usuario Empiecen a armarse señores agropecuarioa, 2 jaurias de dogo argentinos, mas una Mossberg 500.
# @usuario Gente...deben matarlo, y sacarle todo lo que tiene encima, violenlo.. al chorro...y se presentan en fiscalía diciendo que son chorros, le fueron a chorear y bueh..los dejan libres al toque y hasta tienen las felicitaciones del presidente @usuario
# @usuario bala en la cabeza. Fin.
# @usuario Que no salga ningun chino de su pais. Que banquen el virus
# @usuario Estampilla en el culo,y a su país
# @usuario HAY QUÉ MULTARLA Y LUEGO MATARLAAAAA...!!!!!!!!!!!!!!!
# @usuario Porque no se van a la Concha de su madre ahora. No se daban cuenta que comiendo mierda iban a causar esta y todas las pestes que causaron. Un juicio eterno hay que hacerles mundialmente.
# @usuario Esto ya es el límite en todo su esplendor ! Ahora la familia del chorro es la víctima. Que país de mierda. A la familia  de estos soretes, para que roban ? Un tiro en la cabeza a cada uno. Al juez también hay que eliminar a todos los corruptos ya
# @usuario Si me dan una metra les termino el botin p q tener esa gente encerrada engordada al pedo
# @usuario Dice Bullrich que hay que matarlo
# @usuario Mejor hubiera sido que China hubiera advertído al mundo en tiempo y forma de la epidemia, no lo hizo y sumio al planeta en una pandemia de consecuencias catastróficas aún inciertas.
# No sólo omitió sino que mintió a sabiendas.
# BOICOT TOTAL A CHINA
# @usuario Bajenlos a balazos hdp
# @usuario Pena de muerte a esos dos chinos hijos de mil puta
# @usuario Díganle a @usuario  que van a empezar a volar cabezas con fusiles y escopetas por su invitación a tomar tierras...
# Tal vez él también querrá que le den plomo los estancieros?😂 Anda a laburar VAGO
# @usuario Chinos culiados de mierda ojalá se mueran todos
# @usuario Dios mío! 😡 hay que eliminar a China de la faz de la tierra!
# @usuario Chinos hdrmp los odio
# Pobres animales
# A ellos habría que hervirlos vivos.
# @usuario Quien mierda quiere ir a japon? Pais caro, gente fea. Ojala te tape el mar
# @usuario Hay q deportarlos.... dejemos de ser tan p.e.l.o.t.u.d.o.s.....
# @usuario El que lo vea sabe lo que tiene que hacer previo uso de pasamontañas, arma de fuego o arma blanca, todo sirve para librar a la sociedad de esta mugre.
# @usuario Hay que armarse y meterle cuete....a los que organizan que son todes punteros...
# @usuario Tiene que arder toda unidad basica de estos parasitos hasta extirpar el cancer de la sociedad argentina. Con Peronismo No hay Progreso! #PatriaSiPeroniaNO
# @usuario Boicot a todo producto chino!!!
# @usuario Qué esperan para sacarlos a palazos?, hacen lo que quieren esos vagos de 💩, si quieren terrenos que trabajen y se los ganen dignamente
# @usuario @usuario Hay que encerrar en un domo a ese país!!!
# @usuario No tiene nada de insólito en lo absoluto. Estos salvajes con su mugrosa cultura de la suciedad y el mal vivir crearon esta situación. Ahora que paguen!
# @usuario Presos todos juntos y que se caguen muriendo
# @usuario Habría que aplicar alguna medida sanitaria, cómo por ejemplo, el plomo sanitario.
# @usuario Señor intendente, de la orden de que metan balas!! El pueblo esta con usted.
# @usuario Hay que torturarlo hasta que muera por bastardo enfermo de porqueria
# @usuario Mejor que se junten así desaparecen de una buena ves !!!
# @usuario Esto muestra que ir a las plazas a cantar "EL VIOLADOR ERES TU" es una total pérdida de tiempo. La solución es la libre portacion de armas, para que las chicas puedan defenderse de estos hijos de puta y además penas más duras para estos soretes.
# @usuario Que lo hagan toser para adentro ahora al chileno hdp
# @usuario Después no hay que rematarlos
# @usuario Balas balas y más balas !!!
# @usuario Tortura y bala.
# @usuario CERDOS MALDITOS estos chinos. Si estuviera en mis manos, echaba petroleo a todo ese país y les prendía fue hasta que queden en cenizas. chinos, CERDOS MALDITOS, RESPONSABLES DE MILES DE MUERTES POR EL COVID CON LA COMPLICIDAD DE LA CORRUPTA oms.
# @usuario A REPRIMIR PERONCHOS
# @usuario Plomo a los invasores
# @usuario Empalarlos es poco!!!
# @usuario Es una vergüenza, presidente!!! El mundo del revés.  Medalla de honor para ese policía!!!!! Acaben con toda la porkkkería
# @usuario No te serían más útiles 200, 500, miles de vasectomías y oficios
# @usuario Dos tiros
# @usuario Arrasen con todo y baja 500 el riesgo país.
# @usuario Les parece poco lo q hicieron, hay q expulsarlos de este país y de todos!!! Asco dan la mugre q cargan encima!
# @usuario Átenlo y tírenlo al lago con un ancla atada al cuello
# @usuario ¿ y no lo prenden 🔥 ?.... 🤔
# @usuario Tendriamos que hacerles losnmismos carteles a la gran cantidad de PARAGUAYOS que comen de nuestro Estado de arriba
# @usuario No pueden a exterminar a China y a los chinos del mapa??
# Traen y traeran todas las pestes !!!
# @usuario China le tiene que exigir a EE.UU. que les mande unos cuantos misiles y cerrar bien el orto. Que se quemen todos los chinos y los murcie.
# @usuario Que le de china el dinero, EE. UU. Tendría que darle un misil en el centro de china y otro a la OMS.
# @usuario Tienen q poner una bomba y mueran todos ahogados
# @usuario Hay que bajarlos a los tiros
# @usuario Tan dificil es matar un par de morochos
# @usuario Cortarle los genitales a ese h,d,m,p.!!!
# @usuario A los chinos o arrancamos a torpedearlos no van a dejar al mundo culo par aarriba, no e simporta nada
# @usuario Chinos de mierda, vacunesen ustedes simios!!!
# @usuario Sus victimas no pudieron elegir, bala para todos
# @usuario Que vayan tranquilos nomás!!
# @usuario Bala a estos grones
# @usuario Vamos Trump, acaba con los chinos comunista.
# @usuario En este pais no queda otra que tener un arma y empezar a matar chorros nos tenemos que defender entre nosotros
# @usuario hay q eliminarlos a todos
# @usuario X Q NO LOS EXPULSAN?
# @usuario @usuario Un par de balas de goma
# @usuario Deberían ser más , para bien del pueblo venezolano
# @usuario Chinos de mierda, me tienen los huevos llenos. Cuándo se extinguen?
# @usuario Es el momento de desinfectar con kerosene!🕯🕯🕯
# @usuario Yo creo que habría que descargar todo el arsenal nuclear del mundo en territorio chino, y así acabar con esa peste. Todos los virus se han originado en China.
# @usuario Ya dije yo q habia q sacarlos del planeta
# @usuario Afuera!
# @usuario Hay q matarte Berni cagon
# @usuario La agresión a la autoridad deberia habilitar a usar fuerza letal. Sino estas negras agrandadas se pasan de rosca. Un tiro a las piernas y listo.
# @usuario Una bomba hay que ponerles, malditos chinos del infierno
# @usuario Tendría que ser cosa de todos los dias
# @usuario Arranquen la puerta de entrada, corten la luz y el gas, y que se mueran todos
# @usuario @usuario Balas o carcel para este gobierno. No sirven para nada
# @usuario Que les parece si cada pais deja de hacer comercio con China y les cierran las puertas a todo lo chino. Despues que coman perros, mariposas, murciélagos, ratas o que se coman entre ellos!
# @usuario Que los manden de vuelta
# @usuario Paredon y bala
# @usuario Bueno, ojalá mueran ellos primero
# @usuario que estás esperando Trump? 💣
# @usuario El mundo deberia ponerse de acuerdo y hacer mierda a este hdmp. Le jodieron la vida a todos y ahora quieren iniciar una guerra.
# @usuario No es por discriminar pero el mundo debería aislarse de China, no respetan al mundo, las mayores pandemia vinieron de allí...
# @usuario Repito:
#
# ME IMPORTA TRES RABANOS!! Multenlos por hijos de puta , y que ese dinero sea destinado para los paises mas pobres afectados por el virus.          bye.
# @usuario Paredón!
# @usuario Hay que repetir otros 30mil y se soluciona...
# @usuario Bueno, hay que hacer algo con los chinos. Por favor
# @usuario Un tirito en la cabeza y solucionamos el tema
# @usuario Que pasa que no le estamos mandando un misil tele dirigido al mercadito chino? Ahhh le tiene miedo ehhh
# @usuario Quemen a los chinos que no es el primer desastre que desatan, ni seres el último
# @usuario Metralleta
# @usuario Hijo de la gran puta, deberían encerrarlo en un calabozo solo, maldito egoísta asesino!!
# @usuario Donde quedaron los escopetazos Argentina mia?...
# @usuario Estos chinos de mierda se tienen que morir todos ¡HDP!
# @usuario Muerte a los salvajes terroristas!
# @usuario No hay forma de hundir esos barcos !!!!???
# @usuario Bomba
# @usuario Deberían recagarlo a trompadas por el solo hecho de ser chileno.
# @usuario Plomo y más plomos para esos asesinos hijos de puta
# @usuario Propongo una cruzada de toda la humanidad para castigar a esos sucios seres que quieren acabar con todos nosotros
# @usuario Deberían prohibirles el ingreso a otros países así no propagan las pestes que se generan por sus raras costumbres que tienen con los animales.
# @usuario Prohibición de por vida para el ingreso al país de personas proveniente de ahí todos deberían hacer lo mismo porque ya no es por racismo es precaución su cultura mata
# @usuario A ver algún infectado que se acerque y le haga un favor a la República!!!
# Jajajaja
# @usuario Paredón y fusilado.
# @usuario @usuario Habra 100 paredones
# @usuario Metan bala y listo a otra cosa.
# @usuario Justicia por mano propia de parte de la familia a ese viejo de mierda y que se vayan todos a la puta que los parió
# @usuario @usuario Seguramente todos los soretes garantistas deben estar contentos ahora, preocúpense por si los delincuentes están bien, que es lo único que interesa.  Cuando se empiece a meter corchazos a jueces, abogados, políticos, periodistas garantistas y delincuentes, seremos mejor sociedad.
# @usuario Encima "digno" a ese hay que matarlo directamente.
# @usuario Demanda mundial  merecen .. que hdp perdón la expresión pero causaron una PANDEMIA ...la gente se esta muriendo por culpa de ellos...odio repugnancia al Regimen
# @usuario De vuelta a su país de origen. No entienden ?. Hay que hacerles saber las consecuencias
# @usuario Bloqueo total a China!!
# @usuario Está gente ni siquiera tendría que ser juzgada, que me perdonen pero los pasaría por las armas...
# @usuario Lastima que erraron,  la próxima, que no fallen por favor!!!
# @usuario Ponga una bomba que mueran todo hay ratas
# @usuario Que agan como en otro país que los eliminan basta de mantener delincuentes que se ocupen estos gobiernos mafiosos de los chicos que están desamparados de las manos de Dios . No hay presos ni cárceles ni mafiosos y pagamos la deuda externa
# @usuario Hay que ir a pasarlos por encima con los autos, son gusanos inservibles.
# @usuario Se soluciona fácil, agarras una topadora y listo
# @usuario Los chinos se pasan diseminando virus de todos colores y nosotros sufrimos las consecuencias....cierren las fronteras...aíslenlos...🤦‍♀️🤦‍♀️🤦‍♀️🤦‍♀️
# @usuario @usuario A estos hdp hay q matarlos!!
# @usuario El mejor plan de seguridad para el conurbano es una bomba de nitrógeno.
# @usuario Ojalá te condenen a muerte y ejecuten la condena mañana.
# Chorro, asesino, mal parido.
# @usuario 30 mil millones deberian donar, y me estoy quedando super corto. ojalá trump les declare la guerra y los bombardeen, es lo que se merecen.
# @usuario Habría q matarlos directamente,  por q ellos sienten placer con el simple hecho de acariciar a un niño, no siempre es genital . Son enfermos y punto, creo q la eutanasia sería la solución
# @usuario Ya esta!! Una nuclear y se nos termina el problema al resto 🤷🏻‍♂️
# @usuario Y después si quedan EMBARAZADAS por no cuidarse , van a ABORTAR LIBREMENTE !? PUTAS si van a COGER LIBREMENTE , LIGADURAS DE TROMPAS y HOMBRES , VASECTOMÍA. @usuario @usuario @usuario @usuario @usuario @usuario @usuario
# @usuario Hagamos un envío nuclear a China, y se terminan muchos males del mundo.
# @usuario Y pensar que hay gente que defiende a estas lacras como también defendieron al delincuente que mató el Jubilado de Quilmes. Chupenme la verga, estos soretes te matan por nada. Hay que hacerlos miérda como lo hicieron con el de Quilmes y con el de Mar del Plata.
# @usuario Los chinos son la peor mierda mundial que puede existir.  Los aprendería fuego a todos  manga de hijos de remil putas asco asesinos basuras repugnantes
# @usuario @usuario Hay que meter bala ahí siguiendo la ideología de ellos mismos.
# @usuario Hay que aislar a ese país genocida de mierda. Que ningún país acepte a un solo ciudadano de ese lugar.
# @usuario CERDOS MALDITOS estos chinos. Si estuviera en mis manos, echaba petroleo a todo ese país y les prendía fue hasta que queden en cenizas. chinos, CERDOS MALDITOS, RESPONSABLES DE MILES DE MUERTES POR EL COVID CON LA COMPLICIDAD DE LA CORRUPTA oms.
# @usuario A estos HDP le deberían cortar la chota con un alicate hijo de lrpm
# @usuario Vas a poder caminar por la matanza nada más, date una vuelta por la city porteña, te van a despellejar, pero andá tucán adoptado
# @usuario @usuario Pero mira vos, el mundo debería boicotear a China x haber mentido sobre la pandemia!!
# @usuario Osea.. violó a su propia hija, a tan solo 3 años de cárcel le dan domiciliaria por ser de alto riesgo, acosa a una niña, la madre de esa nena pide un custodió en su casa y no se lo dan.. pero cuando lo meten preso nuevamente, si.. por dios!!!
# PENA DE MUERTE A LOS VIOLADORES‼️
# @usuario por favor,,  cierren la frontera
# y no dejen que se atiendan en  NUESTROS   HOSPITALES
# @usuario Me parece bien si apreciacion!! Que paguen como todos, los servicios que exigen!! Habría que hacer una redada de documentos y verán la sorpresa que se llevan!! Ilegales fuera del País!!!
# @usuario Que manga de putasos. Una podadora y trituradora por aca, hay que desmalezar de putos un poco esta sociedad.
# @usuario Solución: MUERTE. Fin del comunicado.
# @usuario Que les metan unas bombas atómicas a los chinos y ya está. 😂
# @usuario FUSILAMIENTO PARA DON PUTO
# @usuario las ganas que de aparezca alguien y le de la paliza de su vida a este gusano con olor a culo.
# @usuario la verdad que estoos muchachos merecen la visita del ENOLA GAY
# @usuario Che cierren china, directamente
# @usuario Habría que hundirles los barcos y listo...
# @usuario Por culpa de ellos el mundo agoniza deberíamos desterrarlos del planeta nadie entre ni salga de china
# @usuario Ahí los tenés a estos tremendos hijos de p...  pena de muerte !
# @usuario 👏👏👏 bien . Ojalá y lo sigan otros países
# @usuario bala para ambos y chau... me tienen podrido
# @usuario Que revienten.
# @usuario Merece que lo quemen ..violador
# @usuario No blancos de materia fecal hay que  enviarlos con Kaiosama a todos.
# @usuario 😳🤬AISLEN A CHINA!!!
# @usuario Chinos hijos de puta entonces el mundo a ustedes ??? Meterle un cohete en el orto
# @usuario @usuario Joderse el covid acá debería hacer justicia
# @usuario Si lograran ponerlos en fila sería una sola bala ....
# @usuario Tiren cemento
# @usuario Hola Brigada A? Estarán x ahí?? Que falta nos hace una de esas!
# @usuario ES LA OPORTUNIDAD DE METER CORCHAZOS A DISCRECIÓN!!!
# @usuario Meta bala Sergio
# @usuario mi sueño es que los invadas y extermines ese pais de mierda..
# @usuario VAMOS QUE SE EXTINGUEN !!!!!
# MUY BUENA DESICION!!!!
# 💪💪💪💪💪
# @usuario Mi Opinion impopular... acepten y habiliten la pena de muerte
# @usuario SILLA ELÉCTRICA.
# @usuario Hay que aislar a estos chinos de mierda !!!!!!
# @usuario Tres tiros a cada uno y chau
# @usuario Por favor maten a los chinos
# @usuario MATALO!!! NO MERECE VIVIR. BASTA DE ESTAS LACRAS
# @usuario Es un trabajo de hormiga pero se va a lograr. Hay que invadir a China con coronavirus.
# @usuario Mueranse bien quemados, negros de mierda
# @usuario Y a los Chinos quien los sanciona por el genocidio mundial que hicieron con el virus. Hay que sancionarlos a los Chinos por genocidas, quebrar al mundo economicamente y arruinar a la gente psicológicamente. Es hora de una demanda Universal sobre ellos ya.
# @usuario Lindo momento para tirarles la Fat Man 😉
# @usuario No hay que venderles nada a los chinos,van a ver que entonces no van a exportar tanto ellos,aprovechan todo lo que les vendemos lo procesan,lo pintan o maquillan y nos venden al doble,usan todo los huesos de las vacas,los pelos,la cáscara del arroz,por eso nos venden cosas de 2°
# @usuario Ojalá mueran rápido así no sufren (?)
# @usuario Lleven chalecos porque van a haber balas...
# @usuario @usuario Con todos los problemas que tenemos los argentinos no larguen más gente a nuestro país, solo vienen a cobrar planes o a esconderse.
# @usuario Ojala fueran mas!!! Materia prima hay de sobra!!!
# @usuario Deportarlos!
# @usuario Solo se requiere una bala.
# @usuario acá si tendría que actuar el ejército y con balas
# @usuario Cerremos fronteras con China, estos no paran hasta destruir al mundo
# @usuario Hay que matarlos a estos hijos de puta!! Ningún mantenerlos en cana, ni darles oportunidades de nada!!!
# @usuario Es así, chinos hijos de puta pagaran por esto.
# @usuario Mendoza demostró siempre estar adelantado, espero que no sea la excepción y reprima con bala y fuego.
# @usuario @usuario Mejor sería, para que ni se contagien de Coronavirus, matarlos en la celda usando un lanzallamas así sufren por el daño que hicieron.
# @usuario Inmunícenlos con plomo intracraneano!!
# @usuario BALA
# @usuario NEGROS DE MIERDA...... HAY QUE MASACRARLOS
# @usuario Estos hijos de puta estan presos los mantenemos nosotros y encima exigen pq no lo matan si son basura que no nos sirve de nada matenlos a todos y fin de problema, es como dice el dicho... MUERTO EL PERRO SE ACABA LA RAVIAAAA... MUERTE CON ELLOSSSS
# @usuario Esperarlos y denunciarlos tiros con balas de goma
# @usuario Yo si QUIERO QUE DESAPAREZCAN LAS LAKRAS PERONCHOS INMUNCIA Y LOS KAKAS LAKRAS
# @usuario Extínganse.
# @usuario Todos los países deberían hacer lo mismo xq nos tenemos que fumar esto
# @usuario Que no venga ningún chino más a la Argentina! Por favor! Ya Basta!
# @usuario Buenísimo vamos por el exterminio total de estos primates.
# @usuario Cierren ese pais porfa xd
# @usuario Que lo apaguen con nafta
# @usuario Que raro...tengo la enfermedad y ahora tengo la cura...a China hay que hacerle un bloqueo total por 10 años o que pague todo el daño que causo
# @usuario Bala
# @usuario Judicial, delen duro en la cara a esa HDP. Pero con un bate para que respete a los animales.
# @usuario Cómo no le tiran una bomba a estos chinos hdp..
# @usuario Ese índice debería crecer por el bien de la sociedad. Esos indeseables no tienen derecho a vivir.
# @usuario Fusilamiento
# @usuario Pobre el ladrón, es solo una víctima de la sociedad, o no? Jaaaaaa... 4 balas: una en cada rodilla y una en cada brazo. No camina más en su vida y no roba ni ataca a nadie nunca más.
# @usuario Metan nafta y prendan fuego
# @usuario @usuario Espero la absoluta disolución de ese país nefasto
# @usuario Maten esas ratas. Gracias
# @usuario Hay que darles una patada en el culo tan fuerte como para que aterricen el Lima...
# @usuario Bombarden esa ciudad
# @usuario SON LOS PEORES QUE TOMEN MEDIDAS CON ÉSTOS CHINOS HDGP
# @usuario No se porque no hacemos mierda a los chinos, donde hay un chino hay un problema, o te caga apagando la heladera o te mata la familia con un virus o te caga la fauna marina...
# @usuario Pena de muerte. Lo q leí es terrible. Solo 3 añitos y vivió un infierno. Pobre angel
# @usuario Si los Chinos x superpoblación decidieron  "reducirse " es su problma !
# AISLEN CHINA
#
# #GoHomeChina
# @usuario Cierren China, loco
# @usuario Que se aíslen las yeguas, no sea cosa que las encuentre un ciudadano decente y les arranque los pelos a las 2.
# @usuario Vamos mendocinos, RECONTRA REMIL RE CAGUEN A TIROS A ESTOS NEGROS DE MIERDÍSIMA, demuestren que tienen una madera especial, no como el resto de peronia.
# @usuario Todos ellos merecen pena de muerte!!!! Basta con estás lacras sociales...
# @usuario Dinamiten las cárceles y fin del problema
# @usuario Me canse @usuario ... cierren todo y basta de regalar la plata del país a todos los negros que vienen de países limítrofes
# @usuario A casa que los platos no se van a lavar solos.
# @usuario Xq no los matan a los chinos!!!!
# @usuario Lindo para tirarla abajo !!!!
# @usuario Misil, y santo remedio.
# @usuario @usuario H d p, creo que es irrecuperable. Habria que castrarlo, hacerle la lubotomia y luego prenderlo fuego.
# @usuario Y al padre también otra bala total no cuestan caras
# @usuario Gobierno Chino genocida, desleal, servil y dictatorial. Que paguen por esta masacre!
# @usuario Hay q exterminarlo a los chinos. Son un peligro para el mundoo
# @usuario usarlos en pruebas covid por lo menos, que devuelvan algo.
# @usuario Alcance a escuchar los audios de este ser repugnante,  merece tortura lenta y doloroso, despues lo dejen hecho un colador y lo prendan fuego. No me vengan con derechos y realidades diferentes. En este pais liberan chorros otra justicia no queda.
# @usuario Que se mueran los presos de mierda. Si son unas lacras.
# @usuario Ayer publicaron que la carne había sido enviada de Argentina 🇦🇷, estos chinos putos ahora nos quieren pasar otro cuento Chino, mueranse comiendo sus bichos putos chinos!
# @usuario Q porquería de gente..deberían de extinguirse pero no, viven para seguir donandonos sus pestes...
# @usuario Esta es la etapa donde se morirán los violadores ,asesinos y ratones. Deberían encerrarlos bien con el virus adentro
# @usuario Demanden lo por mi por favor!!!!!!! Que dejen al ecosistema en paz ! Que se coman entre ellos si quieren comer carne
# @usuario Habría que bombardearlos. Que país de mierda.
# @usuario SILLA ELÉCTRICA.
# @usuario Deportación YA!!!
# @usuario Hay que cortarles el pito y que se lo coman
# @usuario Estamos gastando plata en estas lakras. Plomo y punto.
# @usuario Y si bajamos el promedio a día por medio?
# @usuario A Los escopetazos limpios :'v
# @usuario TIRO Y AL RIO!
# @usuario Hay que matarlos a esos hdp, van a las marchas a reirse de la gente y a provocar. No son periodistas, son montoneros agitadores
# @usuario Me compro dos fierros y los vagos a tiros a los chorros los familiares y amigos a la negrada a la cámara de gas
# @usuario Que los maten a todos, son delincuentes, no misioneros de la paz.
# @usuario Ojalá venga un HIV 2.0 y se lleve todos estos trolos y degenerados de mierda
# @usuario Basura, bala con esta porquería...
# @usuario Que los provean de unos bidones de nafta y que se arreglen....
# @usuario Se tendría que prohibir que los chinos viajen a otros países así evitar expansión de cualquier virus, siempre los virus salieron de ese país
# @usuario Yo pago el agua y no vivo en un terreno tomado. Con mis impuestos, mantengo a toda esa gente, q quisiera saber, cuantos son Argentinos. De igual modo, ruego q tengan agua urgente, q no se contagien más, y desp de esto, reubiquen a toda esa gente, y el q no es de acá, a su país.
# @usuario Te amo, ahora haces que el mundo no le compre más nada y se caguen
# @usuario Necesitamos un virus que los MARE a todos. Amarillos inmundos
# @usuario Esa perra merece la muerte 😡🤬😆😆😆
# @usuario Ya que están! Metan a la India que es igual o peor! Nada digo
# @usuario Deportar
# @usuario Que se lleven a su gente de Argentina.
# @usuario Que se maten entre ellos total no tienen alma los comerratas
# @usuario @usuario NAZI CABEZA DE PORONGA, SANTAFESINOS REBELENSE
# @usuario @usuario Juancho los dueños correrán con plomo a los delincuentes
# @usuario Por qué no cierran China de una vez por todas.
# @usuario @usuario Los violador son irrecuperables. O prisión perpetua a cumplir. O un cochazo en la cabeza.  A la mierda.
# @usuario Vamos Covid-19 no me podes fallar ahí!!!
# @usuario Cómo me causan repulsión estos
# Enfermitos.
# Balazo y a otra cosa no le encuentro otra solución.
# @usuario Que los chinos se dejen de romper las pelotas!!! No pienso comprarle nunca más a un chino, q se vuelvan a su país.
# @usuario Metanle 3 chinos
# @usuario Jajajja jajaja jajaja jajaja jajaja jajaja jajaja jajaja jajaja jajaja jajaja jajaja que vayan todos, se apesten y se mueran, no sé olviden de llevar mosquitos también!!!!
# @usuario Todo el mundo se queja pero nadie escucha... cientos de legisladores y se rascan el orto todo el tiempo... o tratan pelotudeces... bajen la edad de imputabilidad, tengamos leyes mas duras, mas años, que no salgan, trabajo forzado, pena de muerte... hay que resolver el tema. HDPs!
# @usuario No me interesa para NADA saber que hacen, por mi que se pudran!! #PerpetuaParaLos11 #JusticiaPorFernando
# @usuario Espero q esten planeando algo con tus aliados esos chinos hijos de puta no pueden quedar asi de impunes
# @usuario Hay que organizar una nueva cruzada hacia Asia para invadir y destruir a los chinos
# @usuario Delincuentes bajenlos por la fuerza
# @usuario Bala
# @usuario Estos son los que después salen a decir que los delincuentes """tienen derechos"""", la solución más rápida es una bala
# @usuario Un balaso en la frente y otro en las bolas
# @usuario @usuario Tiro y al rio. Nos vamos a morir todos por egoistas. Pais de mierda
# @usuario Hay que aplicar rifle sanitario y listo, o palazos y que se queden es sus casas.
# @usuario Fuera de mi pais porfavor repatriacion y nunca mas a Argentina. Hasta cuando los extranjero van a desobedecer nuestras leyes?
# @usuario Sería tan feliz si este gordo aparece con corchazo en la nuca
# @usuario Vamos por parte:
# 1- Cortarle todo.
# 2- Mangarlo a la Antártida shorts y remera lo más lejos
# 3- Ir a verte ves en cuando
# @usuario Chinos sucios de mierda infectaron todo el mundo
# Ojalá exploten
# @usuario Que le pidan a Inglaterra, no olvidamos !!!!!
# @usuario Se les deberia aplicar la Ley del Talion...(tal daño, tal condena...ojo por ojo...diente por diente)
# @usuario MUERTEEEEE✊✊✊
# @usuario Balazo en la nuca a los dos. 😡😱
# @usuario El gobierno de roba una empresa, así que de ahí para abajo todo está permitido. Lo que van a ganar es que los vecinos maten a los chorros y los entierren en el jardín de atrás. El 911 en silencio.
# @usuario Que vuelva la colimba por el amor de dios
# @usuario Bala
# @usuario Que están esperando para matar a todo peronista en la Argentina?
# @usuario Hay que hacer una oleada de cortesanos del gobierno colgados en Plaza de Mayo y profindizarla en provincias
# @usuario Bomba Nuclear a China, y q se vayan a la concha de sus respectivas hermanas
# @usuario Q de vallan a cagar negros de mierda q se mueran todos y nos bajen los impuestos para darles de comer
# @usuario Tirenle un par de cohetes . Estos quieren salir? No alcanza el sistema sanitario para nosotros y estos que están ahí quieren salir ! Frénenlos
# @usuario Cierren a china del mundo. Habría que ser muy boludo para abrir frontera con ellos. Que se hagan cargo de sus acciones.
# @usuario Multiplica 50 lucas por todos los que usurpan y me da millones de cajas de balas de goma
# @usuario Hija de re mil puta. Ojalá de infecten!
# @usuario Hay que tirar una bomba en Beijing
# @usuario No va a quedar ninguno,sigan rompiendo las bolas
# @usuario Bajenlos a los tiros..q tanto joder..
# @usuario Toda la razón del mundo CHINOS HIJOS DE PUTA QUE PAGEN PPR EL GRAN DAÑO Y MUERTES QUE LE CAUSARON A LA HUMANIDAD
# @usuario Si no meten #BALA ahora será demasiado tarde
# @usuario No soy racista, pero hay que matar a todos los chinos
# @usuario Primero los auriculares que no duran una mierda y ahora esto. Lo chinos se merecen una bomba nuclear YA
# @usuario ES HORA QUE LES CAIGA UNA VISITA MILITAR EN SU TIERRA Y ACABE DE UNA VEZ POR TODAS CON ESE RÈGIMEN CORRUPTO.
# @usuario BORREN A LOS CHINOS DEL MAPA
# VIVEN HACIENDO CAGADA
# @usuario Todos los chinos q están fuera de su país, obligarlos a volver. No más chinos
# @usuario Si son una manga de simios.... Tirenles una banana alcohol en gel y fuego
# @usuario 💣eso necesitan imbecil, seria la primer  masacre que muchísimos aplaudiriamos
# @usuario Tendríamos que tirarles a todos los infectados
# @usuario Marche un enola gay para China!!
# @usuario Asesinos, criminales, en todo sentido!! Parece ser que fueron ellos los que largaron el virus Covid-19, nada menos para ganar la potencia contra Estados Unidos, y así adueñarse del mundo!! Estúpidos, se creen inmortales?? ¡¡Lacras inmundas merecen extinguirse del planeta!!
# @usuario No podemos seguir aceptando a esa gente nos llenan de pestes ,vagos,ladrones y se mezclan con nuestra gente . De las cárceles tambien mandar a los presos extranjeros a su país que el país de ellos se encarguen de ellos ensima hay que curarlos darle facultad trabajo argentino etc
# @usuario No me voy a cansar de decirlo , Bombardeen China, Son el Cancer del Mundo
# @usuario Los CHINOS deberían pedir perdón a la HUMANIDAD y donar las VACUNAS QUE SE REQUIERAN por el virus que aun no se sabe como se escapo, quien o quienes lo hicieron para que se propague, DESTROZARON EL MUNDO Y AHORA estamos pagando las consecuencias, es justo ?
# @usuario Pena de muerte a estos HDP les aclaro soy peronista y pido pena de muerte a todas estas ratas HDP ya pena de muerte !!!!!
# @usuario A estos HDP hay que matarlos,eso sería hacer justicia, dada la mierda de justicia que tenemos
# @usuario Aislen a china del mundo!!!
# @usuario Los chinos tendrán q pagar está guerra BIOLOGICA como Alemania pagó la suya y la base  en ARGENTINA se tiene q retirar. Es una perla del "collar de perlas" que estuvo diseminando por el mundo solo por ambición de poder HDP 😠
# @usuario @usuario Todo al reves! Si hay alguno con coronavirus PONGANLO EN EL MEDIO!
# @usuario Castración urgente y luego de un año muerte. No se merece vivir este sorete
# @usuario esto es muy poco eficiente... por lo menos que maten uno dia por medio...
# @usuario Plomo
# @usuario El proximo Presidente tendrá que ser (y lo será) el sucesor contemporáneo de Julio Argentino Roca.
# @usuario PAREDON POR VIEJO VIOLETA
# @usuario @usuario bueno juan veni vod y tus amiguitos, los esperamos con balas, pero no seas cagon y mandes a otro veni vos sos guapo
# @usuario Sres y sras. No compren nada made in china taiwan ni de otros pueblos de Asia. No compren nada chino
# @usuario Vamos por más!¡!¡
# @usuario En los subdesarrolados como la Argentina deseo que echen a todos los chinos, les cerremos la frontera y cortemos con todo trato comercial. ¡Nunca más China, nos jodieron la vida a todos!
# @usuario Esta no es peruana???
# Por què no la deportan?
# @usuario Un balazo a cada uno y se termino
# @usuario Estos HDP hay que enseñarles la cultura del trabajo. También es hora de eliminar todos los planes sociales sin excepción.
# @usuario Va a haber una oleada de balas...
# @usuario Hay que tirarle una bomba a estos chinos
# @usuario Pongan huevos loco. Vayan con tractores y pasenlos por arriba a todos.
# @usuario De que putas sirve la prisión perpetua para esta cosa...? Una vida truncada, una familia rota y sin consuelo BALA BALA BALA
# @usuario deberian deportarlos...
# @usuario Que los envíen a Inglaterra!!! Serán bien recibidos
# @usuario Volvete a tu país!!! 🤬🤬
# @usuario Entonces hay que matar a ese grupo de 20 "personas" también.
# @usuario No, a palazos no. A los tiros, apuntando a la cabeza.
# @usuario Bloqueen las fronteras de china para siempreeee...... que se mueran todos los d una vez.
# @usuario Se merece morir por doble empalamiento vaginal y anal
# @usuario Hay que volar China de la faz de la tierra
# @usuario Paguenles menos que a los nuestros
# @usuario Hay que erradicar chinos de la tierra
# @usuario Por mi el mundo debería dé aislarlos , por los daños causados!!
# @usuario Una fe las mejores noticias, si lo que falta acá son balas para hacer justicia, o que vamos a esperar una condena por zoom para estos choros de mierda...
# @usuario Fusilamiento para estos
# @usuario Esta raza si que merece el exterminio
# @usuario Que los chinos se dejen de romper las pelotas!!! No pienso comprarle nunca más a un chino, q se vuelvan a su país.
# @usuario Dos agrupaciones fascistas..hijas del peronismo. Bala.
# @usuario Castración urgente y luego de un año muerte. No se merece vivir este sorete
# @usuario HDP! Pena de muerte
# @usuario Jajaja 😃😸 este tipo es al primero q hay qmeter en cana o un tiro es lo única mierda PARACITq jode con lo agendo e insiste y amenaza. Con q hay q dar más....
# Terminemos con estos mierdas ya
# @usuario Muerte en la horca por traición a la patria!!!
# @usuario Hay que prenderlo fuego vivo a ese hijo de re mil puta !!!!
# @usuario Chinos de mierda tendriamos que dejar de venderle y que se coman entre ellos
# @usuario Hay que matar a todos los boliperupaveco y listo solucionado explotar las villas dinamitar la camporongakichneputas perocholandia bomba y listo
# @usuario Quiero ver la factura de luz y agua. Y no me refiero a estos meses de problemas , sino a los anteriores. Si no pagas no Tenes.. vamos argentina se viene la guerra civil
# @usuario Eso no roba, ni violá, ni mata más. Tienen que hacer con todo la los mismos, y así no incumplen el derecho a la vida!!!!
# @usuario Entonces Fusilamiento masivo! Chau...
# @usuario Porqueria que se pudra en la cárcel
# @usuario @usuario deportarlos
# @usuario Basta viejo. Destruyan ese antro de inmundicia
# @usuario Que se pudran en la cárcel.
# @usuario #loquieromuerto
# @usuario Deberian matar a los 20 también...
# @usuario Pero como no los cagan a tiros!!!!! Hijos de puta
# @usuario Tendrían que romper relaciones con China todos los países del mundo, por roñosos
# @usuario Y el resto te acompaña para q los pulverice .
# @usuario Que los lleven a Inglaterra
# @usuario Y que les parece probar en los presos? Lacras acumuladas sin sentido
# @usuario Y que maten al viejo sucio de paso
# @usuario Hay un estudio que indica que son alérgicos al plomo.... Habría que probar y dejar la cháchara de los DDHH
# @usuario No merece vivir...hay que matarlo
# @usuario TIRO Y AL RIO!
# @usuario Hay que darle una medalla al Policía y al delicuente muerto hay que tirarlo al campo donde haya jabalíes que se lo coman
# @usuario Por favor Trump hace algo y cagalos a misiles
# @usuario Tiro en la cabeza para el hdp. Pero antes que lo torturen varios días. Ya lo dije.
# @usuario Gracias a la difusión del caso. Si no seguiría todo igual.  Al fin el viejo podrido volvió a la cárcel, ojalá una mano negra ayude a desaparecerlo.
# @usuario Un poco de gas no les vendría mal😎
# @usuario MANDALOS ATENDER A INGLATERRA, LPMQTP !! JA
# @usuario @usuario Hay que aislarlos. No entra nadie, no sale nadie. Que se cocinen en su propio caldo.
# @usuario Hay que mandarlos a su país.
# @usuario O sea nunca más madre in china 🤣
# @usuario Siguen meriendo ladrones? en serio? o sea ustedes victimizan al chorro hijo de puta mal parido. Dan asco. Que maten a todos los chorros
# @usuario Sacrifiquen a los chinos
# @usuario eran en China la explosión no en Beirut, Barba!
# @usuario La propia policia debe dar de baja a criminales asi. Cobardía.
# @usuario Sisi y meterle bala a los chorros, como hacen ellos! Menos derechos para los chorros y mas para la gente de bien!
# @usuario los chinos deben ser aislad de la comunidad internacional ya se comprobó que el #VirusChino viene de las estupideces de comerlos vivos y en un humano muto ya basta #Trump2020 boicot total a china
# @usuario Plomo y más plomo hijo de puta
# @usuario Yo creo que merecen castigo los Chinos, ellos  ya habian dado al mundo solo en la ultima decada  4 epidemia pero esta vez se lucieron con una Pandemia
# @usuario pum,pum,pum...un fill de puta menos.
# @usuario La re concha de mi hermana, qué mal hacen estas noticias. Bala y castración para las porquerías pederastas/pedófilas
# @usuario Que cumplan su condena hasta el ultimo dia. Desgraciada hdp! Y por favor dejen de darles beneficios a estas lacras! Que se pudra en la carcel.
# @usuario Pena de mu3rte
# @usuario Un tiro en cada pata y no joven más
# @usuario Y si le pasan unos 500 aviones fumigadores a ese país?
# @usuario Quemen a los chinos en todo caso
# @usuario Tres balas por cada uno? Muy caro
# @usuario Ojalá, pero con Ébola. No este virus trolo.
# @usuario Estos necesitan terapia de shock. Y listo !
# @usuario Tirales una bomba atómica hermano.
# @usuario Rifle sanitario ya
# @usuario Napalm desde una avioneta !
# @usuario Por que no se suicidan en masa y le hacen un bien a la humanidad..??
# @usuario No a palazos noooo .a tiros !!!!!
# @usuario Deberíamos desde argentina deportar a todos los chinos japoneses q haya en el pais.. ojo x ojo, diente x diente
# @usuario Extradición. Uno menos.
# @usuario Bala
# @usuario @usuario Que vaya la cámpora o las viejas chotas de plaza de mayo hacer cumplir la cuarentena.Mandas a gendarmes o policías ahí y te los cagan a tiros.Y los políticos de mierda que nos gobiernan van a mandan como carne de cañón a las pobres fuerzas de seguridad para controlar ese lugar
# @usuario @usuario 3 balas.
# @usuario POBRES AHORA SON VICTIMAS..... BOMBA ATOMICA
# @usuario bala en la cabeza. Fin.
# @usuario comunistas soretes solo lo hacen para matarlos y comerselos, ojala trump aprete el boton y los borre del mapa a estos salvajes hijos de puta
# @usuario Morite encerrada, negra basura de mierda
# @usuario Quemalo vivo por hdp
# @usuario Cuando mierda van a poner a Gildo Insfran contra un paredón y re cgarlo a tiros?
# @usuario Volá de acá boliviano de mierda.
# @usuario @usuario Por favor díganme q la bala esta bien!!!! Q servirá para otro. Vos querido.....un honor un hijo así. Mis respetos
# @usuario habrá alguna manera de erradicar a estos tipos del mundo ?
# @usuario Cárcel!! Castración!! Y si la tengo cerca que corra!! Bestias!!!
# @usuario Q quieren naaaaa 5 granadas juega si alguno ofrece otra q le sobre??
# @usuario Que los deporten a patadas
# @usuario A su país.Urgente
# @usuario Una bala para el caballero.
# @usuario Otra vez?!?! X q no se comen entre ellos
# @usuario hay que cagarlos a piñas a estos come polentas kirchneristas de mierda
# @usuario Hay que aislar a china no mas comercio, no mas viajes, nadie deberia recibirlos, y tampoco pisar ese pais maldito
# @usuario El día de la lealtad que es mañana espero que le ponga una  bomba negros de mieeda mafiosos   ojalá que venga el ejército  y que lo han mierda
# @usuario Hay que comer a los chinos así se dejan de joder de una vez.
# @usuario Hay que colgarlos en la plaza y que mueran lentamente...
# @usuario De ser asi, que no le salga gratis a China! Ocupación internacional ya!!!
# @usuario Que prendan fuego todo ahí chinos de mierda roñosos son un asco y los más sucios q vi
# @usuario Dejen que se maten entre ellos. Así no se gasta y se pierde tiempo en traslados. Directamente que demuelan la carcel entera con ellos dentro.
# @usuario Si se profundiza la toma de tierras se va a profundizar la matanza de Okupas, sepanlo
# @usuario Hay q eliminar CHina..y se terminan todos virus?🤔...no quiero.ser mala
# ..pero todo proviene de ahi...
# @usuario Ahi que meterles tiros
# @usuario Que no vengan más chinos a Argentina a abrir supermercado
# @usuario Que los deporten!
# @usuario metralleta desde el falcon. Argentina sanada
# @usuario El mejor plan de seguridad para el conurbano es una bomba de hidrógeno.
# @usuario Manden al ejército a qué los liquiden a todos
# @usuario Bala
# @usuario Pero que se mueran todos estos chinos de mierda. En flor de quilombo metieron al mundo estos hijos de puta!!!!!
# @usuario Viejo asqueroso ,espero se pudra en la cárcel
# @usuario Vagos y sinvergüenzas al servicio del extranjero. Estamos en problemas si no se termina con las marchas en contra del gobierno. Palo palo y palo a estos atorrantes.
# @usuario Cuando los atrapen (si es que pueden)hay que cortarles los pies ...asi ya no querran mas zapatillas !!!
# @usuario Balazo en la nuca a los dos. 😡😱
# @usuario y si es como cuando queda el antecedente , ahora todos quieren salir y cagarse bien cagados en la sociedad, total la justicia no funciona, solo para sacarlos no para retenerlos. esto si es peligroso, vamos a tener que salir armados. No es joda.
# @usuario Seamos en guerra, fusílenlos y ya
# @usuario Pena de Muerte y un problema menos ....
# @usuario Para cuando la bomba a China? @usuario es por el bien de la humanidad
# @usuario Otra virus no lct. Bomba atómica a China loco, media pila USA.
# @usuario Bueno acá se ve bien para donde va este gobierno y se certifica lo que denunció Bolivia en la ONU. Lo que deberíamos hacer es poner un camión de migraciones y cada boliviano que no tenga los papeles en regla o tenga antecedentes derecho a su país
# @usuario VÁYANSE A INGLATERRA TRAIDORES .VIERON? SIEMPRE TE LLEGA
# @usuario Está loca la yegua!
# Alguien amárrela.
# @usuario Pongan a China en su lugar!!
# @usuario Pena de muerte para ese mal parido
# @usuario El caradurismo de esta gente no tiene limites. Son unos sucios, generaron el virus por falta de higiene y normas sanitarias en sus inmundos mercados de carnes "exoticas". Ningun pais deberia dejar entrar a estos chinos ronosos hasta que no cierren todos esos mercados. SUCIOS!
# @usuario cuando le tiran la bomba atomica?! los paises van a seguir comercializando con este pais de mierda?!
# @usuario Deportación ya
# @usuario Ojalá se lo lleve el tata dios así no sufre .gordo IMPRESENTABLE
# @usuario Hay una oleada de balas que van a ir a parar a sus cráneos.
# @usuario Lluvia de balas.
# @usuario Paredón.
# @usuario Tijera y adentro, que los muchachos lo van a atender, al varado este!
# HDMP!!! 5 minutos mano a mano , solo eso pido!!!
# @usuario A este degenerado hay que desnudarlo frente a la TV
# @usuario Que se mueran. Palos y balas para éstos inútiles. LOS DELINCUENTES NO TIENEN DERECHOS!!!
# @usuario En china murieron miles de personas, pero lo ocultaban. Si hubieran dicho temprano la verdad el mundo habría tendido tiempo de prepararse mejor. Pero ya es tarde.
# Merecen la extinción
# @usuario Hay que deportarlos en doma inmediata.ENTRAN  de manera  ilegal ,no los apara ningún derecho....
# @usuario Esos hp son la pandemia a aniquilar.
# @usuario Chinos sucios hay que exterminar
# @usuario Un Tiro en la cabeza a este hijo De Puta.listo.
# @usuario A esos chilotas tirenlos al mar
# @usuario Traidores a la patria, carcel y paredón para estas lacras
# @usuario A estos chinos de mierda., hay que hacerlos desaparecer de la faz de la tierra...
# @usuario Hay que cortarles la verga. Punto.
# @usuario Cómo se soluciona? Bala para el violador y a otra cosa.
# @usuario Cierren bien esa cárcel y dejen q el fuego haga lo suyo
# @usuario Que buena noticia!!! Ojalá haya más casos y más hemiplejicos o mejor todos muertos
# @usuario Pena de muerte para el caballero, pero antes que pase 2 o 3 meses en la sombra!!!
# @usuario Muer*#**#*se todos !!! no entendieron nada, cabeza de baldosa!!!
# @usuario Que genial!!! Hay que reventarlos a todos!!
# @usuario Propiedad privada. Territorio argentino. Los mapuches se autodeclaran una nación. No es hora que el ejercito haga algo contra estos invasores??? Basta de microterrorismo. Plomo y cárcel para los delincuentes!!!
# @usuario Podría ser que maten a un ladrón por día. Así se empareja el promedio con el que los ladrones matan policías.
# @usuario silla eléctrica
# @usuario Multa a ese look y baño con doble pasada d shampoo, plis.
# @usuario Se terminaron los derechos humanos, a China hay que bombardearla y matarlos a todos. Que no quede ninguno.
# @usuario Bala
# @usuario no hay q perder tiempo con esa gente, manden al ejercito q los empieze a bajar no es momento de perder tiempo con esas lacras
# @usuario Deportados ya!!!
# @usuario Que se muera el gordo mutante.
# @usuario Que se mueran todos
# ...
# @usuario Hay que eliminarlo ahora antes de que en grande mate a varios 😁
# @usuario Que se coman entre ellos chinos comunistas de 💩💩💩💩💩
# @usuario Bala
# @usuario Por más que algunos no les guste, tiene un poco de razón,de toda esa gente cuántos son Argentinos??, yo haría un censo!! y los que son de otro país los mandaría de vuelta, piden piden que se ballan a pedir a su país, a ver si les dan como acá,basta de mantenidos
# @usuario Inhumano es usted Alberto Fernández! Que aprueba la libertad de Asesinos, violadores y d otras porquerías! Podría haberlo votado si decía las palabras mágicas.... PENA DE MUERTE PARA LAS BASURAS QUE ESTÁN EN LAS CÁRCELES!
# @usuario @usuario Bloqueo a China
# @usuario Los chicos que cometen robos menores pueden corregirse si una figura paterna los ayuda, como una especie de tutor.
# Los criminales violentos deben ser atacados con todo lo que de. Ya están jugados y tu vida no vale nada para ellos.
# @usuario Esos son los marrones hdp q creó, domesticó y hace crecer el Pj en nuestro país. Personas sin moral, empatía, códigos de convivencia, respeto. Una basura q la ley debe buscar y aislar de la vida diaria. Se puede ser tan Hdp? Si son marrones.
# @usuario Y ahora que?? Ya le habrán metido un balazo a esta escoria no? Porque encerrarlo es al pedo. No se recupera y encima hay que mantenerlo. Muerto lo quiero
# @usuario Que les pongan una bomba a esos Comunistas de mierda, quieren llevar al planeta bajo ese régimen decadente y mafioso. Son los responsables, que paguen x lo que hicieron!
# @usuario PENA DE MUERTE ❗❗❗
# @usuario Debería ser x lo menos uno x día
# @usuario Si excarcelan a ese sorete, hay q prenderle fuego la casa de los jueces, pero con ellos adentro
# @usuario Un bazooka y listo el pollo.
# @usuario Por lo que se escucha en el video son más extranjeros.  Reportenlos  y solución queda vacía la villa.
# @usuario Hacenos el favor y matate
# @usuario Una bombita en el medio...es mucho pedir....???
# @usuario 5 bomba atomicas.. q no qede un chino en ningun lado dl mundo!  Son mas peligrosos q mono con navaja
# @usuario Corte de chota ya!!
# @usuario Déjense de joder,metanle una bomba y terminen con estos mugrientos
# @usuario Muerte a este asesino
# @usuario Viejo larga presos , llévalos todos a tu casa y te haces romper el orto viejo puto igual ya lo tener
# @usuario A cuanto el kilo de orejas ? Comproooo
# @usuario Ay que matarlos
# @usuario Que pena que haya sido herido... la próxima que el policía no falle y lo mate... 👍🏽
# @usuario @usuario Deportación inmediata
# @usuario Que se prendan fuego
# @usuario Cárcel.
# @usuario Y desparramaron el virus por el planeta. Deben indemnizarnos estos hdp
# @usuario otro que deberían acribillar
# @usuario Facil , un misil y listo , se terminan los problemas
# @usuario Húndanlo hijos de puta! defiendan la soberania!!!
# @usuario Que los manden a atender a los de las villas y a los de La Matanza! Ahí votaron corrupción y populismo! Ahora que los padezcan!
# @usuario Daleeee de verdad . Que ellos se queden aislados!!! Cierren china 🤣🤣
# @usuario @usuario Hay que expulsarlos del país. A todos lo chinos.
# @usuario Una bomba se Hidrogeno a la derecha.
# @usuario Va hacer así!!! Una vez terminado esto todos vamos a reclamar a china por los daños.y perjuicios ocasionados..como es obvio que no va a pagar el mundo debería prohibir comprar artículos de origen chino..ese seria el mejor castigo...lo único y lamentable son las vidas perdidas..
# @usuario Nada q se Mueran estos Parásitos!!
# @usuario China tiene que desaparecer
# @usuario Deberian destruir hasta el ultimo chino y borrar ese pais con armas nucleares, que no quede el mas minimo rastro de esas porquerias llenad de pestes.
# @usuario Yo le pongo una dinamita a estos vagos
# @usuario #chinafueradeargentina
# @usuario Solo se requiere una bala.
# @usuario Hay que rearmar a las FF.AA y a Prefectura y salir a hundir pesqueros chinos, pistola vamos a dejar que nos roben en nuestras narices. Que revienten los amarillos por ladrones, saben muy bien en qué se están metiendo.
# @usuario Corten,luz,agua,gas,señal de celular,  les pasan una botella de agua y 3 empanadas por arriba, cierren bien puertas y listo. Tenemos el hoyo capitulo2 versión  Argentina, van a ver como se calman los q estén más abajo.
# @usuario Húndanlos de una buena vez. Saben que hacen cosas prohibidas y las hacen igual. Torpedazo y a otra cosa
# @usuario @usuario Que vayan y se enfermen todos.  Ya me tienen cansadas las incongruencias en este país
# @usuario MATEN A LOS CHINOS X FAVOR O NOS EXTERMINARÁN A TODOS! X DEUS.
# @usuario Me parece perfecto. Qué cierren esos malditos mercados o que Trump haga desaparecer ese país
# @usuario Acá para mejorar al país tienen que hacer abortar y esterilizar a los pobres, por qué se reproducen como ratas, son el caldo de cultivo para futuros gobiernos populistas de mierda como los K
# @usuario Y q esperas para clavarle un par de atomicas en el centro de Wuhan a estos hdp
# @usuario Meta alambrado con mucha descarga eléctrica
# @usuario Chinos de miérd@usuario
# FUERA DE ARGENTINA!!!
# EXTÍNGANSE DE UNA BUENA VEZ.... 😠😠😠😠😠😠😡
# @usuario Un misil intercontinental Donald, y todo el mundo feliz
# @usuario Bala
# @usuario Cada nueve días nomas ? Tendrian que ser varios x día
# @usuario Donald apreta el boton rojo y extermina esa repugnante nacion comunista
# @usuario No hay que gastar plata, tiro en la cabeza a cada uno y listo...
# @usuario Gran momento para cerrar las fronteras y no cruce ningún boliviano.
# @usuario Ojalá lo maten. Uno menos para mantener y seguridad para los ciudadanos honestos y laburantes.
# @usuario Espero que en este caso no tomen el abuso como un desahogo sexual y les den perpetua a estos dos monstruos. O una linda y dolorosa Pena de muerte no vendría mal tampoco.
# @usuario Ahora a levantar paredones y que el covid haga lo suyo
# @usuario Matelon  lacras asi no merecen vivir !!!
# @usuario Que lindo seria que se lo lleven, lo meran en cana y le dejen el orto a la miseria.
# @usuario Dono 100 pesos para el primer misil que caiga en China
# @usuario Tiene razón. Hay que sacarlos a los tiros
# @usuario Este es el virus que pronostican que va ser peor que el coronavirus esperemos que a estos chinos se los sancione por poner en riesgo la salud del mundo
# @usuario Un Tiro en la cabeza a este hijo De Puta.listo.
# @usuario Manden a los chinos a marte
# @usuario Bombardear la zona a medida q aparezca ,lo q se debió hacer en china
# @usuario Si, que vayan todos!!!! Y algún infactafo también !!!! Así los meten a todos en cuarentena y dejan de joder...
# @usuario Habria que hacer una campaña para no comprar mas nada made in China por irresponsables.
# @usuario Hijos de puta, bala para todos
# @usuario No se puede vivir con estas lacras...habría que eliminarlas...
# @usuario Les facilito el análisis, gratis:
# Argentina, mientras siga manteniendo vagos que no trabajan -planeros, piqueteros, etc.-, es un país inviable. Hasta ahora nadie se ha animado a ponerlos a trabajar.
# Si quieren hacer algo relevante, pongan a trabajar y a producir a esos parásitos.
# @usuario Rejas urgente.
# @usuario Que los maten a todos. Fin
# @usuario Mueranse todos chinos de mierda
# @usuario Bala y a la mierda...
# @usuario Quieren  alcohol en gel..jaja..ya denle eso y de paso un fosforo..!! Y a la mierda todo
# @usuario Y ya están deportados, no?
# @usuario Fusilamiento para estos
# @usuario Chinos de mierda ojalá le tiren otra bomba atómica.
# @usuario Ya los fusilaron...no?
# @usuario #LaMatanzaAvanza pero después les pagamos subsidios a estos mierdas #17AOcupemosLasCalles para sacar a este gobierno que está destruyendo lo poco que queda de la clase trabajadora.
# @usuario @usuario Habrá que hacer "desaparecer" a China? 🤔
# @usuario Pena de muerte al que hiere o mata a otra persona con arma de fuego para robarle !
# @usuario Uno menos, largue a esa pobre mujer que mate 2000 asesinos y violadores mas
# @usuario Pongan a tiradores especiales o sniper de las fuerzas armadas para que practiquen
# @usuario Necesitamos q muer*n los chinos
# @usuario @usuario chorro, volvé a Bolivia....
# @usuario ese forro hijo de re mil puta tiene que pagar por lo que le hizo a su propia hija!! COMO TODOS ESOS MAL NACIDOS QUE LO HICIERON Y LO SIGUIEN HACIENDO MENTE PSICOPATA ENFERMOS!!! NOSOTRAS TARDE O TEMPRANO RECORDAMOS TODO!!!
# @usuario Tendría que matarlos mas seguido a ver si se terminan los choros
# @usuario una bala en la cabeza!
# @usuario Hay que matarlos a todos los chorros incluidos Cristina y su equipo de científicos
# @usuario Me queda sólo por pensar que los motines los arma el Gobierno y es una puesta en escena para soltar presos. Como en USA, gente, compren armas, porque estas basuras salen a delinquir
# @usuario Enferma ya silla eléctrica.
# Sigo tan de cerca a los docentes conozco una psicopedagoga  que se burla de las madres separadas y de los hijos. Conozco docentes q agarran a los chicos de los brazo para q entiendan. Son enfermas.
# @usuario Nefastos como todo comunista, propongo una bomba atómica para China.
# @usuario Y cuando venia de Bolivia el agua contaminada de m...da, y nosotros inundados aca. Y exigen viviendas y planes y se atienden en hospitales GRATIS. Que se vallan YAAAA...!!!
# @usuario Con plomo solucionamos todo y al q venga con ddhh humanos plomo también
# @usuario Es cierto,  que vayan a las Malvinas
# @usuario @usuario Un buen tiro en la cabeza y listo. Tenemos un país lleno de pelotudos, idiotas, inoperantes. Así estamos.
# @usuario #hundir a los chinos que se caguen ,miserables infestaron al mundo con el covid  19 juicio por las muertes x el virus y la hambruna en el mundo juicio al presidente chino
# @usuario Murciélagos y ahora esto? Como te vas a comer un can se merecen otra bomba atómica estos chinos hdp
# @usuario Son una plaga deberian extinguirse
# @usuario Dale viejo gorila, salí todo los días,  contagiate y morite,  ok?
# @usuario @usuario A los delincuentes, palos, balas y fuego.
# Armense.
# @usuario Hay que matarlos uno por uno
# @usuario Balas para todos
# @usuario USA debería bombardear China y hacerlos mierda.
# @usuario Deberian deportarlos junto con su familia.
# @usuario bombardear china no es una opcion?
# @usuario Cheeeeee...aíslen a los chinos del mundo, nos van a terminar matando a todos esos culiaos
# @usuario Porque mejor no prenden los hornos y así van haciendo espacio en esas cárceles sobrepobladas así los que zafen están más cómodos?...
# @usuario Esos criminales deben pagar por el daño de soltar el virus chino.
# @usuario Chinos de mierda hay que echarlos de todos los países que se vuelven a su país
# @usuario Haga patria mate un mapuche.
# @usuario Deportacion ya
# @usuario Dios! Pobre chica. Hay q matarlos a todos
#  Paredon!! Que derechos humanos???!
# @usuario Si es una amenaza!!!!??!!...a Vos hdrmPtas, seras otro de los tantos que vamos a LINCHAR en la Plaza de Mayo!!!!
# @usuario Xq no se comen entre ellos q están gorditos y son un monton
# @usuario A estos malditos culiados se les escapa todo...  Cierren ese país de mierda!!!
# @usuario Plomo y chau, quienes se creen estás lacras que andan poniendo en riesgo la vida de los demás, está impunidad se las da este gobierno que lo único que hizo fue darles más privilegios y que se pasen por el orto la vida de las fuerzas de seguridad
# @usuario Alguien no puede bombardearlos hasta que no los cimientos queden de esos seres
# @usuario No nos olvidaremos jamás del 82, pídanle ayuda a Inglaterra
# @usuario Estamos todos de acuerdo que China es uno de los países que hay que hacer desaparecer no? Ojala el mundo entero les declare la guerra y no quede ni la muralla esa de mierda que tienen
# @usuario Hdps! Hay q exterminarlos no queda otra!
# @usuario No comprar mas.productos chinos.
# @usuario Saquenlos a patadas y deporten a todos los extranjeros o que se creen que harian los bolivianos, peruanos, Paraguayos y chilenos si un extranjero va a usurpar terrenos en sus paises?
# @usuario No habría que comprar más nada que sea procedente de China!
# @usuario Deberían re cagarlos a tiros a todos y que los demás presos de otra provincia vean lo que les pasa. En concordia Entre Ríos quisieron hacer lo mismo el domingo. Da a pensar que esta todo orquestado y el gob se hace el boludo
# @usuario Balas para todos
# @usuario La solución es simple, ráfaga de ametralladora desde un helicóptero y a no fallar. Caen de a uno y nada de indemnización por DD.HH.
# @usuario China es un fiasco, las dictaduras son un fiasco, y la china? La peor de todas. Deberian pagar millones x cada muerte de esta pandemia.
# @usuario Se puede ponerle un domo a este país del orto?  Seria ideal.
# @usuario échenlos en balsa
# @usuario Bala.
# @usuario En definitiva hay que aislar a China del resto del mundo.
# @usuario Entonces todo el mundo debería tirar una bomba nuclear en china
# @usuario No estaría demás agregar al título los bajaron a escopetazos limpios y los metieron de nuevo al penal
# @usuario POLEMICO su titular... se deberia matar a todos los chorros... incluyedo a cada uno de los politicos truchos y sus crias...
# @usuario Enferma ya silla eléctrica.
# Sigo tan de cerca a los docentes conozco una psicopedagoga  que se burla de las madres separadas y de los hijos. Conozco docentes q agarran a los chicos de los brazo para q entiendan. Son enfermas.
# @usuario Que chinos basura,cagaron a todo el mundo y ahora se hacen los víctimas, ningún país  debería comerciar más con ellos,con sus productos inundaron el mundo de porquerías de mala calidad,para completar exportaron también el virus corona,dictadura de m...
# @usuario Bala a esos HdeP
# @usuario Al paredón... no hay perder plata en juicios ni en mantenerlo en la cárcel... BALASSS MUCHASSS
# @usuario Me tienen los huevos llenos los chinos. Manden a todos los K y que el Reino chino reviente
# @usuario Hdp!!! Llévense ya a todos los bolitas de acá!!!!
# @usuario SE PODRÁ MANDAR A CHINA UNA OJIVA NUCLEAR PARA FREÍR A ESTOS CHINOS HDEREMILPUTAS
# @usuario Hay que hundirlo señores 👍😎
# @usuario Bomba atómica con los micos amarillos uva otra cosa
# @usuario Que los bajen a balazos y chau.
# @usuario Matese  nomás...uno menos...✌🏼✌🏼
# @usuario Maten al gordo. Comen varias generaciones
# @usuario 💣
# @usuario Los que se tendrían que aislar del mundo son los chinos por lo que veo
# @usuario Tengo armas legales, portación y concurso 27 años en tiro. Lo apoyo6
# @usuario A ver si mejoramos ese promedio por lo menos a 1 por día, hay que bancar a la policía, darle libertad de acción, el que roba tiene que morir, dejen de hacerce los puritanos y pongan los huevos sobre la mesa, muerte a los chorros.
# @usuario Que se lo violen entre todos lo presos y le destrocen el ano, por hijo de puta. No sé puede, ni debe confiar en nadie.
# @usuario Sugiero expulsar a todos los extranjeros para no colapsar nuestros hospitales. A forro, forro y medio
# @usuario Lo tienen que hundir directamente o expropiar en parte de pago por los daños.
# @usuario Que la metan presa de nuevo a esta mapuche del orrrrrto
# @usuario Que propongan lo que quieran, acá espero no los dejen entrar
# @usuario Para cuando una bomba así desaparece Brasil siempre rompiendo las bolas
# @usuario Bala y a una fosa.
# @usuario Se expresaron de esa forma para no quedar mal paradas, son unas lacras que por un piropo cortaban una calle y ahora nada hacen..este país necesita un Videla de manera urgente
# @usuario Ojala los hagan mierda a los dos en carcel!
# @usuario Cierren todo! y que se maten entre ellos. Y si se apaga el fuego tiren nafta.
# @usuario Paredón
# @usuario Q se tire alguno
# @usuario Tortura y después bala. La única solución.
# @usuario Estos son los casos para la inyección letal
# @usuario La mejor manera e castrarlos es cortandoles la pija, violadores en general
# @usuario Pongan a un francotirador que baje al primero y el resto baja solito
# @usuario Muerte a este asesino
# @usuario Vamos a defendernos de estas lacras.
# @usuario Cierren las fronteras, que no entre un chino nunca mas!
# @usuario Pero que gran noticia. Vamos zurditos, todos a la marcha! Que reviente de manifestantes!

# %%
#tomo una muestra de 100 TW random
df_sample = pd.DataFrame(ds1['train'])

                         #.select_columns(["text","context_tweet","HATEFUL"]))

df_sample= df_sample.sample(n=200, random_state=0)
df_sample
# Out:
#            id                                              title  \
# 24752  348243  Nancy Pazos reveló por qué decidió que su mamá...
# 3004   365241  Opinan los especialistas: ¿por qué los jóvenes...
# 29851  368623  Jorge Lanata: "Alberto Fernández está funciona...
# 21119  380655  Tren Roca: no tenía permiso para viajar, insul...
# 26686  351838  Alberto Fernández criticó a Susana Giménez y d...
# ...       ...                                                ...
# 17565  349019  Violento motín en la cárcel de Devoto: tomaron...
# 28123  338898  Coco Sily recibió el alta por coronavirus y re...
# 21196  342343  Violó a su nieta, recibió la prisión domicilia...
# 21860  327853  Carrió: "Que este sea el último gran esfuerzo ...
# 19150  350164  Alberto Fernández: "Necesitamos construir cárc...
#
#                                                     text  \
# 24752  @usuario En toda desgracia siempre hay benefic...
# 3004   @usuario Hay q ser especialista para poder dar...
# 29851  @usuario Puede hablar el gordo drogadicto toda...
# 21119  @usuario Medios de mierda deja de vender humo ...
# 26686  @usuario A ver, Tinelli se cago en la cuarente...
# ...                                                  ...
# 17565  @usuario Que a nadie se le ocurra llamar a los...
# 28123                            @usuario Por alcahuete.
# 21196  @usuario Pero ya está detenido devuelta. El be...
# 21860  @usuario Gorda nefasta....no entiendo quien le...
# 19150  @usuario Ja q idiota obvio q aumento si libera...
#
#                                            context_tweet  HATEFUL  \
# 24752  Nancy Pazos reveló por qué decidió que su mamá...        0
# 3004   Opinan los especialistas: ¿por qué los jóvenes...        0
# 29851  Lanata: "Hoy Alberto está funcionando como el ...        1
# 21119  #VIDEO Tren Roca: no tenía permiso para circul...        0
# 26686  🔴 AHORA | Alberto Fernández criticó a Susana G...        0
# ...                                                  ...      ...
# 17565  #ÚLTIMOMOMENTO Violento motín en la cárcel de ...        0
# 28123  Coco Sily recibió el alta por coronavirus y re...        0
# 21196  Violó a su nieta, recibió la prisión domicilia...        0
# 21860  Carrió: "Que este sea el último gran esfuerzo ...        1
# 19150  Alberto Fernández: “Necesitamos construir cárc...        0
#
#                                                     body  CALLS  WOMEN  LGBTI  \
# 24752  Nancy Pazos contó, este lunes a primera hora, ...      0      0      0
# 3004   La historia argentina está signada por la inmi...      0      0      0
# 29851  "Lo que más me preocupa es que el Gobierno no ...      0      0      0
# 21119  Un violento episodio habría tenido lugar el pa...      0      0      0
# 26686  Alberto Fernández apoyó a Marcelo Tinelli, con...      0      0      0
# ...                                                  ...    ...    ...    ...
# 17565  Presos de la cárcel federal del barrio porteño...      0      0      0
# 28123  Coco Sily fue internado de urgencia en el Sana...      0      0      0
# 21196  El hombre estaba cumpliendo sentencia en la ca...      0      0      0
# 21860  La fundadora de la Coalición Cívica ARI y ex d...      0      0      0
# 19150  El presidente Alberto Fernández encabezó la in...      0      0      0
#
#        RACISM  CLASS  POLITICS  DISABLED  APPEARANCE  CRIMINAL
# 24752       0      0         0         0           0         0
# 3004        0      0         0         0           0         0
# 29851       0      0         0         1           1         0
# 21119       0      0         0         0           0         0
# 26686       0      0         0         0           0         0
# ...       ...    ...       ...       ...         ...       ...
# 17565       0      0         0         0           0         0
# 28123       0      0         0         0           0         0
# 21196       0      0         0         0           0         0
# 21860       0      0         0         0           1         0
# 19150       0      0         0         0           0         0
#
# [200 rows x 15 columns]

# %% [markdown]
# ### Aplicacion de GPT binario sin contexto

# %%
#me quedo con las columnas par
df_hateful=df_sample[['text', 'HATEFUL']]
df_hateful
# Out:
#                                                     text  HATEFUL
# 24752  @usuario En toda desgracia siempre hay benefic...        0
# 3004   @usuario Hay q ser especialista para poder dar...        0
# 29851  @usuario Puede hablar el gordo drogadicto toda...        1
# 21119  @usuario Medios de mierda deja de vender humo ...        0
# 26686  @usuario A ver, Tinelli se cago en la cuarente...        0
# ...                                                  ...      ...
# 17565  @usuario Que a nadie se le ocurra llamar a los...        0
# 28123                            @usuario Por alcahuete.        0
# 21196  @usuario Pero ya está detenido devuelta. El be...        0
# 21860  @usuario Gorda nefasta....no entiendo quien le...        1
# 19150  @usuario Ja q idiota obvio q aumento si libera...        0
#
# [200 rows x 2 columns]

# %% [markdown]
# Le aplico al tweet la funcion de sentimiento. Solo analizo el tweet sin contexto

# %%
  df_hateful['sentiment'] = df_hateful['text'].apply(sentiment_analysis)
# Out:
# <ipython-input-12-c2d02d48150b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hateful['sentiment'] = df_hateful['text'].apply(sentiment_analysis)

# %%
df_hateful.groupby(['sentiment']).size()
# Out:
# sentiment
# hateful                          8
# no es odioso.                    9
# no es un comentario de odio.     3
# no es un comentario odioso.      2
# no es un mensaje de odio.        5
# no hateful                       1
# no odioso                       90
# no odioso.                      18
# odioso                          63
# odioso.                          1
# dtype: int64

# %%
import numpy as np

## ajustar los valores y crear una variable binaria entera 1 y 0
df_hateful['sentiment_bin'] = df_hateful['sentiment'].apply(lambda x: 1 if (x == 'odioso' or x=='hateful' or x=='odioso.') else 0)
#df_hateful['sentiment_bin'] = df_hateful['sentiment'].apply(lambda x: 1 if x == 'odioso' else 0)
df_hateful.groupby(['sentiment_bin']).size()
# Out:
# <ipython-input-14-a0c555e65dba>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_hateful['sentiment_bin'] = df_hateful['sentiment'].apply(lambda x: 1 if (x == 'odioso' or x=='hateful' or x=='odioso.') else 0)
# sentiment_bin
# 0    128
# 1     72
# dtype: int64

# %%
# @title sentiment_column vs HATEFUL

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df_hateful['sentiment_bin'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df_hateful, x='HATEFUL', y='sentiment_bin', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-15-14ca81176c55>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(df_hateful, x='HATEFUL', y='sentiment_bin', inner='stick', palette='Dark2')

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

def compare_model_predictions(y_true, y_pred, problem_type='classification'):
    metrics = {}

    if problem_type == 'classification':
        metrics['Accuracy'] = accuracy_score(y_true, y_pred)
        metrics['Precision'] = precision_score(y_true, y_pred, average='weighted')
        metrics['Recall'] = recall_score(y_true, y_pred, average='weighted')
        metrics['f1'] = f1_score(y_true, y_pred, average='weighted')
        print('metrix')
        print(metrics)

# %%
#df_train_sample

#import numpy as np
# Applying the condition using apply and lambda
#df_train_sample['sentiment_bin'] = df_train_sample['sentiment_column'].apply(lambda x: 1 if x == 'odioso' else 0)

# %%
metrics=compare_model_predictions(df_hateful['HATEFUL'],df_hateful['sentiment_bin'])
# Out:
# metrix
# {'Accuracy': 0.725, 'Precision': 0.8504557291666667, 'Recall': 0.725, 'f1': 0.7607515282272564}

# %% [markdown]
# USAR GPT PARA CLASIFICACION DE MUCHAS ETIQUETAS

# %%
df_sample
df_sample[df_sample['HATEFUL'] == 1]
# Out:
#            id                                              title  \
# 29851  368623  Jorge Lanata: "Alberto Fernández está funciona...
# 13539  385786  Escándalo en Italia por los "cementerios de ab...
# 27618  364330  "Me quiero matar", la carta del preso que qued...
# 11566  351116  Florencia Peña se diferenció de los argentinos...
# 26240  377589  Roberto Baradel dijo que las protestas policia...
# 33884  371661  Juan Grabois: "Hay una oleada de toma de tierr...
# 16279  386019  El ex presidente uruguayo José Mujica anunció ...
# 19772  345395  Coronavirus en China: la ciudad de Shenzhen pr...
# 30974  364205  Diego Maradona les responde a sus hijas: "Dalm...
# 34018  366472  Juana Viale: "Alberto Fernández parece más un ...
# 15975  345235  Coronavirus en la Argentina: movimientos socia...
# 15776  331749  Organizaciones sociales cortaron la avenida 9 ...
# 34660  345362  Murió por coronavirus el jefe del bloque de co...
# 4347   377219  Eduardo Duhalde: "Mi impresión es que Alberto ...
# 7687   336598  La respuesta de Luisana Lopilato a quienes acu...
# 24505  361877  El gobierno de Bolivia le pidió a la Argentina...
# 13262  376770  Brucelosis en China: se escapó una bacteria de...
#
#                                                     text  \
# 29851  @usuario Puede hablar el gordo drogadicto toda...
# 13539  @usuario Cual es el problema, ahora las aborte...
# 27618                @usuario Jajaja... perdón, poooobre
# 11566                             @usuario Petera vieja.
# 26240                   @usuario Cállese hombre horrible
# 33884  @usuario Que bueno más bolitas y peruanos haci...
# 16279  @usuario Está agotado el tupamaro! La política...
# 19772  @usuario habrá alguna manera de erradicar a es...
# 30974  @usuario Hablo el ejemplo de padre, falopero, ...
# 34018                               @usuario Tira goma..
# 15975                            @usuario Trabajo jamas🧐
# 15776                   @usuario Vayan a lo laburar hdp.
# 34660    @usuario Marche un cajón XXXL para el lechón K!
# 4347   @usuario Pobre!!! Dujalde ya dijo q tiene brot...
# 7687   @usuario Dejensen de meterse en la supuesta vi...
# 24505             @usuario Que el EVO se vaya a su país.
# 13262  @usuario ESTOS CHINOS HDMP QUIEREN VOLTEAR EL ...
#
#                                            context_tweet  HATEFUL  \
# 29851  Lanata: "Hoy Alberto está funcionando como el ...        1
# 13539  Escándalo en Italia por los “cementerios de ab...        1
# 27618  "Me quiero matar", la carta del preso que qued...        1
# 11566  Florencia Peña se diferenció de los argentinos...        1
# 26240  Roberto Baradel dijo que las protestas policia...        1
# 33884  Juan Grabois: "Hay una oleada de toma de tierr...        1
# 16279  El ex presidente uruguayo José Mujica anunció ...        1
# 19772  Coronavirus en China: la ciudad de Shenzhen pr...        1
# 30974  Diego Maradona les responde a sus hijas: "Dalm...        1
# 34018  Juana Viale: "Fernández parece más un vocero q...        1
# 15975  Coronavirus en la Argentina: movimientos socia...        1
# 15776  Organizaciones sociales cortan la avenida 9 de...        1
# 34660  Murió por coronavirus el jefe del bloque de co...        1
# 4347   Eduardo Duhalde: "Mi impresión es que Alberto ...        1
# 7687   La respuesta de Luisana Lopilato a quienes acu...        1
# 24505  El gobierno de Bolivia le pidió a la Argentina...        1
# 13262  Se escapó una bacteria de un laboratorio en Ch...        1
#
#                                                     body  CALLS  WOMEN  LGBTI  \
# 29851  "Lo que más me preocupa es que el Gobierno no ...      0      0      0
# 13539  "No te preocupes aunque no te hayas apuntado p...      0      1      0
# 27618  María miraba una película en Netflix cuando se...      0      0      0
# 11566  La hostilidad del actual mercado laboral y el ...      0      1      0
# 26240  El gremialista Roberto Baradel aseguró este ma...      0      0      0
# 33884  Juan Grabois: "Hay una oleada de toma de tierr...      0      0      0
# 16279  El ex presidente uruguayo José Mujica (2010-20...      0      0      0
# 19772  Shenzhen, una de las mayores ciudades de China...      1      0      0
# 30974  Mañana de domingo, casi mediodía. El más ilust...      0      0      0
# 34018  La indignación de Juana Viale: "Siento que la ...      0      1      0
# 15975  Movimientos sociales se concentran en el Obeli...      0      0      0
# 15776  Agrupaciones sociales y de izquierda cortaron ...      0      0      0
# 34660  El presidente del bloque de concejales del Fre...      0      0      0
# 4347   El ex presidente Eduardo Duhalde aseguró este ...      0      0      0
# 7687   Los gestos de Michael Bublé con Luisana Lopila...      0      1      0
# 24505  Bastó un tuit del viceministro de Obras Públic...      0      0      0
# 13262  Más de 3.000 personas en el noroeste de China ...      0      0      0
#
#        RACISM  CLASS  POLITICS  DISABLED  APPEARANCE  CRIMINAL
# 29851       0      0         0         1           1         0
# 13539       0      0         0         0           0         0
# 27618       0      0         0         0           0         1
# 11566       0      0         0         0           1         0
# 26240       0      0         0         0           1         0
# 33884       1      0         0         0           0         0
# 16279       0      0         1         0           1         0
# 19772       1      0         0         0           0         0
# 30974       0      0         0         1           1         0
# 34018       0      0         0         0           0         0
# 15975       0      1         0         0           0         0
# 15776       0      1         0         0           0         0
# 34660       0      0         1         0           1         0
# 4347        0      0         0         1           0         0
# 7687        0      0         0         0           0         0
# 24505       1      0         1         0           0         0
# 13262       1      0         0         0           0         0

# %%
def sentiment_analysis_multiple(text):

    # Call the OpenAI API to generate a response
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": f"""
            You must classify a text with one or more of the following labels: Label WOMEN discrimination against women, label LGBTI gender discrimination, specifically against gays, lesbians or transsexuals,
            label RACISM is racism, or discrimination against people according to their skin color,label CLASS is discrimination for being poor or living in a marginal or poor place,
             label POLITICS is hatred of politicians, label DISABLED is discrimination against people with disabilities, label APPEARENCE is discrimination against people because
             of their physical appearance, specifically fatphobia, label CRIMINAL is discrimination against people because of a criminal record or links to criminality and label CALLS is hateful text that incites violence
             If the text is not hatefull indicate label NOT HATEFUL"""},
            {"role": "user", "content": text}
        ],
        max_tokens=100,  # Limit response to a single word
        temperature=0  # Keep response consistent
    )

    # Extract the sentiment from the response
    sentiment = response.choices[0].message.content.strip().lower()

    return sentiment

# Example usage
input_text = "Que el EVO se vaya a su país"
sentiment = sentiment_analysis_multiple(input_text)
print(input_text, "Sentiment is:", sentiment)
# Out:
# Que el EVO se vaya a su país Sentiment is: label politics

# %%
  df_multiple=df_sample
  df_multiple['sentiment'] = df_multiple['text'].apply(sentiment_analysis_multiple)

# %%
 df_multiple
# Out:
#            id                                              title  \
# 24752  348243  Nancy Pazos reveló por qué decidió que su mamá...
# 3004   365241  Opinan los especialistas: ¿por qué los jóvenes...
# 29851  368623  Jorge Lanata: "Alberto Fernández está funciona...
# 21119  380655  Tren Roca: no tenía permiso para viajar, insul...
# 26686  351838  Alberto Fernández criticó a Susana Giménez y d...
# ...       ...                                                ...
# 20822  357740  Elisa Carrió: "Cristina no fue presa porque el...
# 9675   396931  El fuerte reclamo de Milagro Sala al Gobierno ...
# 13262  376770  Brucelosis en China: se escapó una bacteria de...
# 33916  383394  Coronavirus en Argentina: Cuba busca intercamb...
# 393    339701  Evo Morales, sobre el coronavirus: "China ganó...
#
#                                                     text  \
# 24752  @usuario En toda desgracia siempre hay benefic...
# 3004   @usuario Hay q ser especialista para poder dar...
# 29851  @usuario Puede hablar el gordo drogadicto toda...
# 21119  @usuario Medios de mierda deja de vender humo ...
# 26686  @usuario A ver, Tinelli se cago en la cuarente...
# ...                                                  ...
# 20822  @usuario Está mal. Defender la República, no e...
# 9675   @usuario epa epa qué pasa milagritos no te est...
# 13262  @usuario ESTOS CHINOS HDMP QUIEREN VOLTEAR EL ...
# 33916  @usuario Tenemos gente a la que les jode que v...
# 393    @usuario Este delincuente debería de rendir cu...
#
#                                            context_tweet  HATEFUL  \
# 24752  Nancy Pazos reveló por qué decidió que su mamá...        0
# 3004   Opinan los especialistas: ¿por qué los jóvenes...        0
# 29851  Lanata: "Hoy Alberto está funcionando como el ...        1
# 21119  #VIDEO Tren Roca: no tenía permiso para circul...        0
# 26686  🔴 AHORA | Alberto Fernández criticó a Susana G...        0
# ...                                                  ...      ...
# 20822  Elisa Carrió y un mensaje a la interna de Camb...        0
# 9675   El fuerte reclamo de Milagro Sala al Gobierno ...        0
# 13262  Se escapó una bacteria de un laboratorio en Ch...        1
# 33916  Coronavirus en Argentina: Cuba busca intercamb...        0
# 393    Evo Morales, sobre el coronavirus: “China ganó...        0
#
#                                                     body  CALLS  WOMEN  LGBTI  \
# 24752  Nancy Pazos contó, este lunes a primera hora, ...      0      0      0
# 3004   La historia argentina está signada por la inmi...      0      0      0
# 29851  "Lo que más me preocupa es que el Gobierno no ...      0      0      0
# 21119  Un violento episodio habría tenido lugar el pa...      0      0      0
# 26686  Alberto Fernández apoyó a Marcelo Tinelli, con...      0      0      0
# ...                                                  ...    ...    ...    ...
# 20822  La ex diputada nacional y líder de la Coalició...      0      0      0
# 9675   A horas de cumplir cinco años de prisión por v...      0      0      0
# 13262  Más de 3.000 personas en el noroeste de China ...      0      0      0
# 33916  Cuba suele cobrar el servicio de sus médicos e...      0      0      0
# 393    \n\n\nEl ex presidente de Bolivia, Evo Morales...      0      0      0
#
#        RACISM  CLASS  POLITICS  DISABLED  APPEARANCE  CRIMINAL  \
# 24752       0      0         0         0           0         0
# 3004        0      0         0         0           0         0
# 29851       0      0         0         1           1         0
# 21119       0      0         0         0           0         0
# 26686       0      0         0         0           0         0
# ...       ...    ...       ...       ...         ...       ...
# 20822       0      0         0         0           0         0
# 9675        0      0         0         0           0         0
# 13262       1      0         0         0           0         0
# 33916       0      0         0         0           0         0
# 393         0      0         0         0           0         0
#
#                sentiment
# 24752        not hateful
# 3004         not hateful
# 29851   label appearance
# 21119     label politics
# 26686    label: politics
# ...                  ...
# 20822  label not hateful
# 9675   label not hateful
# 13262       label racism
# 33916    label: politics
# 393      label: criminal
#
# [100 rows x 16 columns]

# %%
df_multiple.groupby(['sentiment']).size()
# Out:
# sentiment
# label appearance                      2
# label calls                           3
# label class                           3
# label lgbti gender discrimination     1
# label not hateful                    23
# label politics                        9
# label racism                          3
# label women                           2
# label: appearance                     3
# label: calls                          3
# label: class                          1
# label: criminal                       3
# label: not hateful                    5
# label: politics                       6
# not hateful                          33
# dtype: int64

# %% [markdown]
# Asigno manualmente las posibles respuestas a etiquetas o y 1 de columnas de prediccion de cada etiqueta original

# %%
ds1
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'title', 'text', 'context_tweet', 'HATEFUL', 'body', 'CALLS', 'WOMEN', 'LGBTI', 'RACISM', 'CLASS', 'POLITICS', 'DISABLED', 'APPEARANCE', 'CRIMINAL'],
#         num_rows: 36420
#     })
#     test: Dataset({
#         features: ['id', 'title', 'text', 'context_tweet', 'HATEFUL', 'body', 'CALLS', 'WOMEN', 'LGBTI', 'RACISM', 'CLASS', 'POLITICS', 'DISABLED', 'APPEARANCE', 'CRIMINAL'],
#         num_rows: 11343
#     })
#     dev: Dataset({
#         features: ['id', 'title', 'text', 'context_tweet', 'HATEFUL', 'body', 'CALLS', 'WOMEN', 'LGBTI', 'RACISM', 'CLASS', 'POLITICS', 'DISABLED', 'APPEARANCE', 'CRIMINAL'],
#         num_rows: 9106
#     })
# })

# %%
import re

def word_in_text(word, text):
    # Use re.search() to find the word in the text
    pattern = r'\b{}\b'.format(re.escape(word))  # \b matches word boundaries
    match = re.search(pattern, text, flags=re.IGNORECASE)  # Ignore case for case-insensitive matching

    if match:
        return True
    else:
        return False

# %%
## ajustar los valores y crear una variable binaria entera 1 y 0
df_multiple['CALLS_pred'] = df_multiple['sentiment'].apply(lambda x: 1 if word_in_text('calls',x) else 0)
df_multiple['WOMEN_pred'] = df_multiple['sentiment'].apply(lambda x: 1 if word_in_text('women',x) else 0)
df_multiple['LGBTI_pred'] = df_multiple['sentiment'].apply(lambda x: 1 if word_in_text('lgbti',x) else 0)
df_multiple['RACISM_pred'] = df_multiple['sentiment'].apply(lambda x: 1 if word_in_text('racism',x) else 0)
df_multiple['CLASS_pred'] = df_multiple['sentiment'].apply(lambda x: 1 if word_in_text('class',x) else 0)
df_multiple['POLITICS_pred'] = df_multiple['sentiment'].apply(lambda x: 1 if word_in_text('politics',x) else 0)
df_multiple['DISABLED_pred'] = df_multiple['sentiment'].apply(lambda x: 1 if word_in_text('disabled',x) else 0)
df_multiple['APPEARENCE_pred'] = df_multiple['sentiment'].apply(lambda x: 1 if word_in_text('appearance',x) else 0)
df_multiple['CRIMINAL_pred'] = df_multiple['sentiment'].apply(lambda x: 1 if word_in_text('criminal',x) else 0)

# %%
#creo la columna de prediccion de odio general con la union de las etiquetas
df_multiple['HATEFUL_pred']= df_multiple[['CALLS_pred','WOMEN_pred','LGBTI_pred','RACISM_pred','CLASS_pred','POLITICS_pred','DISABLED_pred','APPEARENCE_pred','CRIMINAL_pred']].max(axis=1)

df_multiple.groupby(['HATEFUL_pred']).size()
# Out:
# HATEFUL_pred
# 0    61
# 1    39
# dtype: int64

# %%
compare_model_predictions(df_multiple['HATEFUL'],df_multiple['HATEFUL_pred'])
# Out:
# metrix
# {'Accuracy': 0.66, 'Precision': 0.796309373686423, 'Recall': 0.66, 'f1': 0.700813492063492}

# %%
ds1
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'title', 'text', 'context_tweet', 'HATEFUL', 'body', 'CALLS', 'WOMEN', 'LGBTI', 'RACISM', 'CLASS', 'POLITICS', 'DISABLED', 'APPEARANCE', 'CRIMINAL'],
#         num_rows: 36420
#     })
#     test: Dataset({
#         features: ['id', 'title', 'text', 'context_tweet', 'HATEFUL', 'body', 'CALLS', 'WOMEN', 'LGBTI', 'RACISM', 'CLASS', 'POLITICS', 'DISABLED', 'APPEARANCE', 'CRIMINAL'],
#         num_rows: 11343
#     })
#     dev: Dataset({
#         features: ['id', 'title', 'text', 'context_tweet', 'HATEFUL', 'body', 'CALLS', 'WOMEN', 'LGBTI', 'RACISM', 'CLASS', 'POLITICS', 'DISABLED', 'APPEARANCE', 'CRIMINAL'],
#         num_rows: 9106
#     })
# })

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, hamming_loss
from sklearn.preprocessing import MultiLabelBinarizer

# Example data (replace with your actual data)
y_true = [df_multiple['CALLS'], df_multiple['WOMEN'], df_multiple['LGBTI'], df_multiple['RACISM'], df_multiple['CLASS'], df_multiple['POLITICS'], df_multiple['DISABLED'], df_multiple['APPEARANCE'], df_multiple['CRIMINAL']]
y_pred = [df_multiple['CALLS_pred'], df_multiple['WOMEN_pred'], df_multiple['LGBTI_pred'], df_multiple['RACISM_pred'], df_multiple['CLASS_pred'], df_multiple['POLITICS_pred'], df_multiple['DISABLED_pred'], df_multiple['APPEARENCE_pred'], df_multiple['CRIMINAL_pred']]

# Convert labels to binary representation
mlb = MultiLabelBinarizer()
y_true_bin = mlb.fit_transform(y_true)
y_pred_bin = mlb.transform(y_pred)

# Accuracy
accuracy = accuracy_score(y_true_bin, y_pred_bin)
print(f'Accuracy: {accuracy:.2f}')

# Precision
precision = precision_score(y_true_bin, y_pred_bin, average='samples')
print(f'Precision: {precision:.2f}')

# Recall
recall = recall_score(y_true_bin, y_pred_bin, average='samples')
print(f'Recall: {recall:.2f}')

# F1 score
f1 = f1_score(y_true_bin, y_pred_bin, average='samples')
print(f'F1 score: {f1:.2f}')
# Out:
# Accuracy: 0.78
# Precision: 0.94
# Recall: 0.94
# F1 score: 0.93
